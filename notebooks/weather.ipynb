# %%
# Add the project root to the Python path
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..'))

from src.config.logging_config import setup_logging
from src.extract.weather_data import fetch_weather_data

# %%
logger = setup_logging(log_file="weather_data.log")

df = fetch_weather_data("2025-01-01", "2025-01-03")
# Out:
# 2025-09-29 18:53:15,801 - src.extract.weather_data - INFO - Fetching weather data from 2025-01-01 to 2025-01-03
# 2025-09-29 18:53:15,803 - src.data_sources.weather - INFO - Fetching historical weather data from 2025-01-01 to 2025-01-03
# 2025-09-29 18:53:15,853 - src.data_sources.weather - INFO - Successfully processed 3 weather records
# 2025-09-29 18:53:15,854 - src.extract.weather_data - INFO - Weather data collection complete! Total records: 3
# 2025-09-29 18:53:15,854 - src.extract.weather_data - INFO - Creating DataFrame from 3 records
# 2025-09-29 18:53:15,855 - src.extract.weather_data - INFO - Weather data collection complete! Total records: 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 3 non-null      datetime64[ns, UTC]
#  1   weather_code         3 non-null      float32
#  2   temperature_2m_mean  3 non-null      float32
#  3   temperature_2m_max   3 non-null      float32
#  4   temperature_2m_min   3 non-null      float32
#  5   sunrise              3 non-null      int64
#  6   sunset               3 non-null      int64
#  7   daylight_duration    3 non-null      float32
#  8   sunshine_duration    3 non-null      float32
#  9   precipitation_sum    3 non-null      float32
#  10  rain_sum             3 non-null      float32
#  11  snowfall_sum         3 non-null      float32
#  12  precipitation_hours  3 non-null      float32
#  13  wind_speed_10m_max   3 non-null      float32
#  14  wind_gusts_10m_max   3 non-null      float32
#  15  sunrise_time         3 non-null      datetime64[ns]
#  16  sunset_time          3 non-null      datetime64[ns]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](2), float32(12), int64(2)
# memory usage: 396.0 bytes

# %%
df = fetch_weather_data("2025-09-30", "2025-10-01")
df.info()
# Out:
# 2025-09-29 18:53:15,955 - src.extract.weather_data - INFO - Fetching weather data from 2025-09-30 to 2025-10-01
# 2025-09-29 18:53:15,957 - src.data_sources.weather - INFO - Fetching forecast weather data from 2025-09-30 to 2025-10-01
# 2025-09-29 18:53:15,994 - src.data_sources.weather - INFO - Successfully processed 2 weather records
# 2025-09-29 18:53:15,995 - src.extract.weather_data - INFO - Weather data collection complete! Total records: 2
# 2025-09-29 18:53:15,996 - src.extract.weather_data - INFO - Creating DataFrame from 2 records
# 2025-09-29 18:53:15,997 - src.extract.weather_data - INFO - Weather data collection complete! Total records: 2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 2 non-null      datetime64[ns, UTC]
#  1   weather_code         2 non-null      float32
#  2   temperature_2m_mean  2 non-null      float32
#  3   temperature_2m_max   2 non-null      float32
#  4   temperature_2m_min   2 non-null      float32
#  5   sunrise              2 non-null      int64
#  6   sunset               2 non-null      int64
#  7   daylight_duration    2 non-null      float32
#  8   sunshine_duration    2 non-null      float32
#  9   precipitation_sum    2 non-null      float32
#  10  rain_sum             2 non-null      float32
#  11  snowfall_sum         2 non-null      float32
#  12  precipitation_hours  2 non-null      float32
#  13  wind_speed_10m_max   2 non-null      float32
#  14  wind_gusts_10m_max   2 non-null      float32
#  15  sunrise_time         2 non-null      datetime64[ns]
#  16  sunset_time          2 non-null      datetime64[ns]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](2), float32(12), int64(2)
# memory usage: 308.0 bytes
