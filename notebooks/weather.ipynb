# %%
# Add the project root to the Python path
import sys
import os
import pandas as pd
sys.path.append(os.path.join(os.getcwd(), '..'))

from src.config.logging_config import setup_logging
from src.extract.weather_data import fetch_weather_data

# Reload modules when code is changed (uncomment for development)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
logger = setup_logging(log_file="weather_data.log")

df = fetch_weather_data("2016-10-01", "2016-10-02")
# Out:
# 2025-10-09 19:11:04,408 - src.extract.weather_data - INFO - Fetching weather data from 2016-10-01 to 2016-10-02
# 2025-10-09 19:11:04,409 - src.data_sources.weather - INFO - Fetching historical weather data from 2016-10-01 to 2016-10-02
# 2025-10-09 19:11:04,419 - src.data_sources.weather - INFO - Successfully processed 2 weather records
# 2025-10-09 19:11:04,419 - src.extract.weather_data - INFO - Weather data collection complete! Total records: 2
# 2025-10-09 19:11:04,420 - src.extract.weather_data - INFO - Creating DataFrame from 2 records
# 2025-10-09 19:11:04,424 - src.transform.weather_transformer - INFO - Weather data formatting complete! Processed 2 records.
# 2025-10-09 19:11:04,425 - src.extract.weather_data - INFO - Weather data collection complete! Total records: 2

# %%
df.head()
# Out:
#         date  weather_code  temperature_2m_mean  temperature_2m_max  \
# 0 2016-10-01          53.0            14.094833             18.8365
# 1 2016-10-02          53.0            12.326084             14.8365
#
#    temperature_2m_min     sunrise      sunset  daylight_duration  \
# 0             10.5865  1475300633  1475342431       41795.472656
# 1             10.3365  1475387128  1475428700       41569.531250
#
#    sunshine_duration  precipitation_sum  rain_sum  snowfall_sum  \
# 0       36650.582031                1.2       1.2           0.0
# 1       34481.562500                1.3       1.3           0.0
#
#    precipitation_hours  wind_speed_10m_max  wind_gusts_10m_max  \
# 0                  3.0           18.391737           45.719997
# 1                  4.0           25.582806           51.480000
#
#                sunrise_time               sunset_time
# 0 2016-10-01 07:43:53+02:00 2016-10-01 19:20:31+02:00
# 1 2016-10-02 07:45:28+02:00 2016-10-02 19:18:20+02:00
