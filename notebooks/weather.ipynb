# %%
# Add the project root to the Python path
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..'))

from src.config.logging_config import setup_logging
from src.extract.weather_data import fetch_weather_data

# %%
logger = setup_logging()

df = fetch_weather_data("2025-01-01", "2025-01-03")
# Out:
# 2025-09-27 10:37:55,920 - src.extract.weather_data - INFO - Fetching weather data from 2025-01-01 to 2025-01-03
# 2025-09-27 10:37:55,922 - src.data_sources.weather - INFO - Fetching weather data from 2025-01-01 to 2025-01-03
# 2025-09-27 10:37:55,956 - src.data_sources.weather - INFO - Successfully processed 3 weather records
# 2025-09-27 10:37:55,957 - src.extract.weather_data - INFO - Weather data collection complete! Total records: 3
# 2025-09-27 10:37:55,957 - src.extract.weather_data - INFO - Creating DataFrame from 3 records
# 2025-09-27 10:37:55,958 - src.extract.weather_data - INFO - Weather data collection complete! Total records: 3

# %%
df.head()

# TODO: fix sunrise and sunset
# Out:
#                        date  weather_code  temperature_2m_mean  \
# 0 2025-01-01 00:00:00+00:00          63.0             6.644001
# 1 2025-01-02 00:00:00+00:00          73.0             2.739834
# 2 2025-01-03 00:00:00+00:00          51.0             0.641917
#
#    temperature_2m_max  temperature_2m_min  sunrise  sunset  daylight_duration  \
# 0            8.868999               3.119        0       0       28995.429688
# 1            5.719000               0.569        0       0       29065.738281
# 2            2.769000              -1.281        0       0       29141.431641
#
#    sunshine_duration  precipitation_sum   rain_sum  snowfall_sum  \
# 0           0.000000          10.200000  10.200000          0.00
# 1       22633.167969           9.700001   8.799999          0.63
# 2       20559.496094           0.100000   0.100000          0.00
#
#    precipitation_hours  wind_speed_10m_max  wind_gusts_10m_max sunrise_time  \
# 0                  6.0           35.302494           75.959999   1970-01-01
# 1                 10.0           14.039999           28.440001   1970-01-01
# 2                  1.0           15.133923           34.200001   1970-01-01
#
#   sunset_time
# 0  1970-01-01
# 1  1970-01-01
# 2  1970-01-01
