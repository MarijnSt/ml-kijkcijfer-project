# %%
from src.weather_data import get_historical_weather_data

#df = get_historical_weather_data(start_date = "2015-01-01", end_date = "2025-05-17")
df = get_historical_weather_data(start_date = "2025-09-14", end_date = "2025-09-15")
df.head()
# Out:
#                        date  weather_code  temperature_2m_mean  \
# 0 2025-09-14 00:00:00+00:00          63.0            15.404414
# 1 2025-09-15 00:00:00+00:00          55.0            16.760668
#
#    temperature_2m_max  temperature_2m_min     sunrise        sunrise_time  \
# 0              19.219              10.419  1757827029 2025-09-14 05:17:09
# 1              19.069              13.969  1757913522 2025-09-15 05:18:42
#
#        sunset         sunset_time  daylight_duration  sunshine_duration  \
# 0  1757872752 2025-09-14 17:59:12       45720.066406       26000.595703
# 1  1757959015 2025-09-15 17:56:55       45490.273438       39902.457031
#
#    precipitation_sum  rain_sum  snowfall_sum  precipitation_hours  \
# 0                4.4       4.4           0.0                  3.0
# 1                3.7       3.7           0.0                 11.0
#
#    wind_speed_10m_max  wind_gusts_10m_max
# 0           26.650946           55.799999
# ...
